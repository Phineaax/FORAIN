# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path_to_FORAIN = "/content/drive/MyDrive/M1/CartaData/Forain/FORAIN"

# %%
from glob import glob
import os
import shutil

# %%
path_to_output = "/content/drive/MyDrive/M1/CartaData/Forain/ToKeep"

path_to_file = os.path.join(path_to_FORAIN, f"ALLEMAGNE/FO-A-1644.tif")
output_path = os.path.join(path_to_output, f"ALLEMAGNE/FO-A-1644.tif")
os.makedirs(os.path.dirname(output_path), exist_ok=True)
try:
  shutil.copy(path_to_file, output_path)
except:
  print(f"Erreur: {path_to_file}")

path_to_folder = os.path.join(path_to_FORAIN, f"ANGLETERRE")
ENG_FILES = ["IMG_0110.tif", "IMG_0023.tif"]
os.makedirs(os.path.dirname(output_path), exist_ok=True)
for file_name in ENG_FILES:
  path_to_file = os.path.join(path_to_folder, file_name)
  output_path = os.path.join(path_to_output, f"ANGLETERRE/{file_name}")
  try:
    shutil.copy(path_to_file, output_path)
  except:
    print(f"Erreur: {path_to_file}")

path_to_folder = os.path.join(path_to_FORAIN, f"ARCHIVES DE JEAN LOUP FORAIN")
JLF_FILES = ["JLF-001_1.tif", "JLF-002_1.tif"]
os.makedirs(os.path.dirname(output_path), exist_ok=True)
for file_name in JLF_FILES:
  path_to_file = os.path.join(path_to_folder, file_name)
  output_path = os.path.join(path_to_output, f"ARCHIVES DE JEAN LOUP FORAIN/{file_name}")
  try:
    shutil.copy(path_to_file, output_path)
  except:
    print(f"Erreur: {path_to_file}")

path_to_file = os.path.join(path_to_FORAIN, f"C Florence VALDES-FORAIN/valdes lot C-019.jpg")
output_path = os.path.join(path_to_output, f"C Florence VALDES-FORAIN/valdes lot C-019.jpg")
os.makedirs(os.path.dirname(output_path), exist_ok=True)
try:
  shutil.copy(path_to_file, output_path)
except:
  print(f"Erreur: {path_to_file}")
# Out:
# Erreur: /content/drive/MyDrive/M1/CartaData/Forain/FORAIN/ARCHIVES DE JEAN LOUP FORAIN/JLF-001_1.tif
# Erreur: /content/drive/MyDrive/M1/CartaData/Forain/FORAIN/ARCHIVES DE JEAN LOUP FORAIN/JLF-002_1.tif

# %%
from IPython.utils import path
path_to_catalogue = os.path.join(path_to_FORAIN, "CATALOGUE RAISONNE")
toKeep = ["FO-0002_4", "FO-0002_2", "FO-0009_5", "FO-0010_2", "FO-0010_9", "FO-0013_4", "FO-0015_7", "FO-0016_6", "FO-0017_2",
          "FO-0019_2", "FO-0020_1", "FO-0021_1", "FO-0025_3", "FO-0155_2"]

for file_path in glob(f"{path_to_catalogue}/**/*.tif"):
  basename = os.path.basename(file_path)
  basename = basename.split(".")[0]

  if basename in toKeep:
    output_path = os.path.join(path_to_output, f"CATALOGUE RAISONNE/{basename}.tif")
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    try:
      shutil.copy(file_path, output_path)
    except:
      print(f"Erreur: {file_path}")

# %%
path_to_corresp = os.path.join(path_to_FORAIN, "NUMERISATION/ARCHIVES/CORRESPONDANCE")
toKeep = ["FO-A-006", "FO-A-012_2", "FO-A-018", "FO-A-012_1", "FO-A-023_1", "FO-A-031_1", "FO-A-034", "FO-A-467_2", "FO-A-575_2", "FO-A-606_2",
"FO-A-631_2", "FO-A-676_2", "FO-A-714_2", "FO-A-726_2", "FO-A-778_1", "FO-A-841_1", "FO-A-931_2", "FO-A-1010", "FO-A-1111", "FO-1-1155_2",
"FO-1244_1", "FO-A-1425", "FO-A-1701", "FO-A-1763"]

for file_path in glob(f"{path_to_corresp}/*.tif"):
  basename = os.path.basename(file_path)
  basename = basename.split(".")[0]

  if basename in toKeep:
    output_path = os.path.join(path_to_output, f"CORRESPONDANCE/{basename}.tif")
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    try:
      shutil.copy(file_path, output_path)
    except:
      print(f"Erreur: {file_path}")

# %%
path_to_nabots = os.path.join(path_to_FORAIN, "NUMERISATION/NABOTS")
toKeep = ["FO-NABOTS-CARNET-TEXTES_10", "FO-NABOTS-CARNET-TEXTES_27", "FO-NABOTS-FAMILLES-CENESSITEUSES_06", "FO-NABOTS-PANTOMIME-1_07"]

for file_path in glob(f"{path_to_nabots}/**/*.tif"):
  basename = os.path.basename(file_path)
  basename = basename.split(".")[0]

  if basename in toKeep:
    output_path = os.path.join(path_to_output, f"NABOTS/{basename}.tif")
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    try:
      shutil.copy(file_path, output_path)
    except:
      print(f"Erreur: {file_path}")
